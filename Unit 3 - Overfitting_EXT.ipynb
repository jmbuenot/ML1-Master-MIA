# %% [markdown]
# # Overfitting
#
# One of the most important issues in Machine Learning is to understand the difference between training and testing errors. The training process will allow the ANN parameters (weights and bias) to be modified to minimise the loss in the **set of patterns used for training**.  If this set of patterns is sufficiently representative, then the ANN will perform well in its working environment, i.e. with new patterns that are not in the training set.  On the other hand, if this set of patterns has not been well chosen, the ANN could not work well with new patterns.  The only way to know this is precisely to evaluate the ANN with new patterns and calculate the error with these **test patterns**.  Since the test set is available from the beginning, this evaluation with the test set is done at the same time as with the training set (but only the training set is used for training).
#
# Therefore, to assess how well trained an ANN is, this can be done by evaluating the test set, not the training set.  Usually there is only one set of data, so it is usually divided into two subsets: training and test. There are several alternatives to perform this division; in these tutorials, two different ones will be performed:
#
# * **Hold Out**. In this method, an experiment is performed with a simple partition of the data set, leaving a certain percentage for testing, usually between 20% and 30%.
#
# * **Cross-validation**.  Here, the data set is divided into $k$ disjoint subsets in order to perform the corresponding $k$ experiments.  In the k-th experiment, the $k$-th set is separated for testing, and trained with the remaining $k-1$.  A usual value of $k$ is 10, so you have a 10-fold crossvalidation.
#
# More specifically, in this session we will focus on the first one, leaving the second one for a later one.  The hold out technique allows us to split the data set into two subsets: training and test.  The training subset allows to adjust the parameters of the model (connection weights and bias), while the test subset allows to check (test) the behavious of a trained ANN (or, any kind of model that is being used, such as a decision tree) on new patterns, not present in the training set.
#
# ![Normal training in the left, and an overfitting curve on the right](./img/Overfitting.png)
#
# Given a well-chosen (and therefore sufficiently representative) training set, the training process could be similar to the figure on the left, with both training and test errors decreasing with each cycle. However, in general, it cannot be ensured that the training set is as noise-free and well-chosen as desirable, so that **overtraining** or **overfitting** often occurs during training.  This can be clearly seen in the figure on the right, where both errors are decreasing until a point is reached where the test error starts to increase.   From that point on, the system starts to overfit.
#
# To avoid overfitting, in ANNs there are a series of techniques known as regularisation techniques, each of which is very different in nature, but all of which aim to avoid overtraining.  Although these techniques are dealt with in much greater depth in other subjects in the programme, e.g. Deep Learning I, in these tutorials we are going to study one of the most well-known techniques, seen in the theory session, called Early Stopping.
#
# In this technique, instead of dividing the initial set of samples into 2 subsets, we create 3 subsets: training, validation and test.  The training and test sets perform the functions described above. The purpose of the validation set is to avoid overfitting by controlling the training process, but it is not used to modify weights or bias.  There are several ways to control the training process, here we will use two of them together:
#
# * A new criteria for stopping the training process.   With the definition of a new parameter: the maximum number of consecutive cycles without improving the *loss* in the validation set.  If these cycles elapse without improving the best validation *loss* achieved so far, the training is stopped.  As the validation set is not used to modify weights or bias, it gives an estimate of what the test error could be.  Therefore, when the validation error increases, it increases the error in patterns that it has not seen, so it is estimated that the test error would increase, and the network would be overtraining.
#
#
# * Once the training process has stopped, the validation set determines which network is returned.  During all the training cycles, the loss is calculated in the training set, which is necessary to modify weights and bias, but also in the validation set.   Once the training is stopped, the ANN is returned corresponding not to the last cycle, but to the cycle with the lowest error in the validation set.  This is done because it is estimated that this ANN is the one that will give the lowest error in the test set, i.e. the one that will behave better with new patterns and, consequently, the one that will generalise better.
#
# Once the training process has stopped and an ANN has been returned, the test set can be evaluated to assess how well the ANN has been trained.
#
# > **Important**: The errors (or accuracies, or any metric used) in the training and validation sets are interesting, but the one that really matters is the test set.
#
# However, most of the time you have all 3 sets (training, validation and test) from the beginning, so as you evaluate the training and validation sets, you also evaluate the test set, which is useful for plotting graphs. However, these values in the test set cannot be used for decision making.

# %% [markdown]
# ### Question
# If what we want to achieve is an ANN with the lowest possible test error, why not choose the ANN corresponding to the cycle with the lowest test error?

# %% [markdown]
# Because the ANN could get specificy for that test set and not generalise for all datasets.

# %% [markdown]
# Therefore, in the training loop it is necessary to keep a reference to the best validation error found so far.  It is also necessary to keep a copy of the ANN that has given that validation error.  Both elements should be updated every cycle when the validation error improves. It is also necessary to keep a counter of how many consecutive cycles the validation error has not improved.
#
# As can be seen, the test set cannot have any involvement in the training process. This is the right thing to do, since an ANN with completely new patterns is being evaluated. However, from a very strict point of view, there is one part in this whole process where the test set is having a small influence: in the normalisation of the data.
#
# Usually the starting point is a dataset that is first normalised and then split into training/test.  If this is done in this way, the patterns used for testing have some influence on the calculation of the normalisation parameter values, which would not be correct. However, the impact they usually have on these parameters and in general on the performance of the ANN is so low, that this is usually not taken into account and all patterns are normalised together.  In any case, the really correct pipeline to do would be divide the data into train test, to calculate the values of the normalisation parameters only with the training set, and the applied that parameters of normalization to the test prior to run the usual training process. Addtionally, if there is a validation data, it can be used on the normalization, too.
#
# For this assignment, you are asked to perform two sets of experiments, one without using validation and the other using a validation set.  More specifically, the requirements are:
#
# 1. Develop a function called `holdOut` that given two parameters, `N` (equal to the number of patterns) and `P` (value between 0 and 1, indicating the percentage of patterns that will be separated for the test set), returns a tuple with two vectors with the indices of the patterns that will be used for training and testing.  The sum of lengths of both vectors has to be equal to N, and these two vectors have to be disjoint.
#
#   This function can be done in a very simple way using the function `randperm` (to use it, load the module with `using Random`).
#
#   From this function, splitting a database into two subsets is done immediately.

# %%
using Random;
using Flux.Losses;
using Pkg; Pkg.add("Flux");


function holdOut(N::Int, P::Real)
    #TODO
    @assert(0<=P<1);
    
    indexes = randperm(N);
    perc = Int(ceil(N*P));
    test = indexes[1:perc];
    train = indexes[(perc+1):N];

    @assert((length(train) + length(test)) == N)
    
    return(train,test);
end
# Out:
#     Updating registry at `C:\Users\Brais\.julia\registries\General.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\Brais\.julia\environments\v1.9\Project.toml`
#   No Changes to `C:\Users\Brais\.julia\environments\v1.9\Manifest.toml`
# holdOut (generic function with 1 method)

# %% [markdown]
# 2. Develop another function called `holdOut`, the same as the previous one and, based on it, which takes 3 parameters: `N` (number of patterns), `Pval` (rate of patterns in the validation set) and `Ptest` (rate of patterns in the test set), and returns a tuple with 3 vectors, with the indices of the elements of the training, validation and test sets. The sum of the lengths of these 3 vectors has to be equal to `N`.
#
#  To do this, simply make two calls to the previously developed `holdOut` function.

# %%
function holdOut(N::Int, Pval::Real, Ptest::Real)
    #TODO
    @assert((Pval + Ptest)<1);

    P_val_test = Pval + Ptest;

    N_val_test = Int(ceil(N*P_val_test));

    (train, val_test) = holdOut(N, P_val_test);
    (ind_val, ind_test) = holdOut(N_val_test, Pval/(1 - Ptest));

    val = val_test[ind_val];
    test = val_test[ind_test];

    @assert((length(val) + length(train) + length(test)) == N);
    
    return (train, val, test)
end
# Out:
# holdOut (generic function with 2 methods)

# %% [markdown]
# 3. Modify the function for training the ANN developed in the previous session to accept the following *optional* parameters in addition to those defined in the previous practice:
#   - **Validation set**, of type `Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,2}}`, i.e. a tuple of 2 arrays: inputs and targets. Default value to empty arrays.
#   - **Test set**, of type `Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,2}}`, i.e. a tuple of 2 arrays: inputs and targets. Default value to empty arrays.
#   - **maxEpochsVal**, of type `Int`, which defines the number of cycles without improving the best validation loss found so far that have to elapse to stop training. In other words, it defines a new stop criterion. Default value should be set to 20.
#
#   With these parameters, this function should implement the early stopping strategy, for which it is necessary to take care that the ANN returned at the end of the function must be:
#     - If a validation set has been given as a argument (i.e. if it is not empty), the ANN to be returned does not have to be the one being trained, but the one with the best validation error.
#     - If no validation set has been passed as a parameter (i.e. if it is empty), the ANN to be returned should be the one corresponding to the last training cycle.  Consequently, the new training function should work in the same way as the previous one in case no validation set is given.
#
#   Additionally, from the trained ANN, this function should return a history of the loss values obtained in the training, validation and test sets in each cycle, as a vector each.
#
#   - To add elements to the end of a vector, refer to the function `push!`
#   - It should be noted that the loss values obtained with the ANN with random weights, prior to training, are usually considered as cycle 0.
#
#   As stated in the previous description, it will be necessary to store the best ANN achieved so far and update it in some iterations of the loop.  To do this, you cannot simply make an assignment to a new variable, since you would only assign the pointer, which would point to the same memory address with the ANN that would be modified in the next iteration.  To make a copy of an object in such a way that all objects (and data, as in this case weights and bias) it contains are also copied, recursively, you can use the function `deepcopy`.

# %%
function trainClassANN(topology::AbstractArray{<:Int,1},
            trainingDataset::Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,2}},
            validationDataset::Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,2}}=
                    (Array{eltype(trainingDataset[1]),2}(undef,0,0), falses(0,0)),
            testDataset::Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,2}}=
                    (Array{eltype(trainingDataset[1]),2}(undef,0,0), falses(0,0)),
            transferFunctions::AbstractArray{<:Function,1}=fill(σ, length(topology)),
            maxEpochs::Int=1000, minLoss::Real=0.0, learningRate::Real=0.01,
            maxEpochsVal::Int=20, showText::Bool=false)

    (train_inputs, train_targets) = trainingDataset;
    (val_inputs, val_targets) = validationDataset;
    (test_inputs, test_targets) = testDataset;
    

    @assert(size(train_inputs,1)==size(train_targets,1));
    @assert(size(val_inputs,1)==size(val_targets,1));
    @assert(size(test_inputs,1)==size(test_targets,1));

    ann = buildClassANN(size(train_inputs,2), topology, size(train_targets,2));
    annMinError = undef
    loss(model,x,y) = (size(y,1) == 1) ? Losses.binarycrossentropy(model(x),y) : Losses.crossentropy(model(x),y);

    trainingLosses = Float32[];
    valLosses = Float32[];
    testLosses = Float32[];

    numEpoch = 0;
    numEpochVal = 0;
    minValLoss = 100;
    trainingLoss = loss(ann, train_inputs', train_targets');
    push!(trainingLosses, trainingLoss);

    valLoss = loss(ann, val_inputs', val_targets');
    push!(valLosses, valLoss);

    testLoss = loss(ann, test_inputs', test_targets');
    push!(testLosses, testLoss);
    
    println("Epoch ", numEpoch, ": train loss : ", trainingLoss, ": validation loss : ", valLoss, ": test loss :", testLoss);

    opt_state = Flux.setup(Adam(learningRate), ann);


    if isempty(validationDataset)
    
        while (numEpoch<maxEpochs) && (trainingLoss>minLoss)
    
            # For each epoch, we have to train and consequently traspose the pattern to have then in columns
            Flux.train!(loss, ann, [(train_inputs', train_targets')], opt_state);
    
            numEpoch += 1;
            trainingLoss = loss(ann, train_inputs', train_targets');
            push!(trainingLosses, trainingLoss);
            testLoss = loss(ann, test_inputs', test_targets');
            push!(testLosses, testLoss);
            # shown it
            
            println("Epoch ", numEpoch, ": train loss : ", trainingLoss,": test loss : ",testLoss);
                
        end;
        
        return(ann, trainingLosses, test,Losses)
    
    else
    
        while (numEpoch<maxEpochs) && (trainingLoss>minLoss) && (numEpochVal<maxEpochsVal)
    
            Flux.train!(loss, ann, [(train_inputs', train_targets')], opt_state);
    
            numEpoch += 1;
    
            numEpochVal+=1;
            
            # calculate the loss for this epoch
            trainingLoss = loss(ann, train_inputs', train_targets');
            # store it
            push!(trainingLosses, trainingLoss);
            # shown it
            
            valLoss = loss(ann, val_inputs', val_targets');
            push!(valLosses, valLoss);
    
            testLoss = loss(ann, test_inputs', test_targets');
            push!(testLosses, testLoss);
            
    
            println("Epoch ", numEpoch, ": train loss: ", trainingLoss, ": validation loss :", valLoss, ": test loss :", testLoss);
    
            if valLoss < minValLoss
    
                minValLoss = valLoss;
                
                numEpochVal = 0;
                
                annMinError = deepcopy(ann);
            end;
                
        end;
        
        return (annMinError, trainingLosses, valLosses, testLosses)
            
    end;
    
end;

# %% [markdown]
# 4. Since there were two versions of the ANN training function (the second accepted a vector as desired outputs), modify this function in the same way so that the targets are vectors instead of arrays for the two-class classification case. Note that in this case the types of the training, validation and test sets passed as parameters will be `Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,1}}` for all three and therefore it will be necessary to call the function `reshape` on all three.

# %%
function trainClassANN(topology::AbstractArray{<:Int,1},
        (train_inputs, train_targets)::Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,1}},
        (val_inputs, val_targets)::Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,1}}= 
                    (Array{eltype(trainingDataset[1]),2}(undef,0,0), falses(0)),
        (test_inputs, test_targets)::Tuple{AbstractArray{<:Real,2}, AbstractArray{Bool,1}}= 
                    (Array{eltype(trainingDataset[1]),2}(undef,0,0), falses(0));
        transferFunctions::AbstractArray{<:Function,1}=fill(σ, length(topology)),
        maxEpochs::Int=1000, minLoss::Real=0.0, learningRate::Real=0.01,
        maxEpochsVal::Int=20, showText::Bool=false)

    trainClassANN(topology, (train_inputs, reshape(train_targets, length(train_targets), 1)), (val_inputs, reshape(val_targets, length(val_targets),1)),
        (test_inputs, reshape(test_targets, length(test_targets), 1)); transferFunctions=transferFunctions, maxEpochs=maxEpochs, minLoss= minLoss,
        learningRate=learningRate, maxEpochsVal=maxEpochsVal, showText=showText)
end
    #TODO
# Out:
# trainClassANN (generic function with 12 methods)

# %% [markdown]
# Remember to integrate the code developed in previous sessions to validate the following pipeline:
#
# 1. Load the database, having the patterns in rows and desired attributes and outputs in columns.
#
# 2. Use the function `holdOut` to split the data set into training, validation and test with the desired percentages. These percentages can be equal to 0.  You will therefore have 6 matrices: inputs and targets in training, validation and test (some may be empty if the corresponding percentage is 0).
#
# 3. Calculate the parameter values corresponding to the type of normalisation to be used with your data (maximum/minimum or mean/standard deviation for each attribute) from the training set only.
#   * This part does not ask to normalise the training set, but to calculate the normalisation values from the training set.
# 4. With these parameters for normalisation calculated in the previous step, normalise training, validation and test sets.
# 5. Train different architectures, and, for each one of them, draw graphs of the evolution of the training, validation and test loss values in the same graph, including cycle 0.

# %%
using DelimitedFiles;
using Statistics;

function accuracy(outputs::AbstractArray{Bool,1}, targets::AbstractArray{Bool,1}) 
    mean(outputs.==targets);
end;

function oneHotEncoding(feature::AbstractArray{<:Any,1},      
        classes::AbstractArray{<:Any,1})
    # First we are going to set a line as defensive to check values
    @assert(all([in(value, classes) for value in feature]));
    
    # Second defensive statement, check the number of classes
    numClasses = length(classes);
    @assert(numClasses>1)
    
    if (numClasses==2)
        # Case with only two classes
        oneHot = reshape(feature.==classes[1], :, 1);
    else
        #Case with more than two clases
        oneHot =  BitArray{2}(undef, length(feature), numClasses);
        for numClass = 1:numClasses
            oneHot[:,numClass] .= (feature.==classes[numClass]);
        end;
    end;
    return oneHot;
end;

oneHotEncoding(feature::AbstractArray{<:Any,1}) = oneHotEncoding(feature, unique(feature));

oneHotEncoding(feature::AbstractArray{Bool,1}) = reshape(feature, :, 1);

function calculateMinMaxNormalizationParameters(dataset::AbstractArray{<:Real,2})
    return minimum(dataset, dims=1), maximum(dataset, dims=1)
end;

function calculateZeroMeanNormalizationParameters(dataset::AbstractArray{<:Real,2})
    return mean(dataset, dims=1), std(dataset, dims=1)
end;

function normalizeMinMax!(dataset::AbstractArray{<:Real,2},      
        normalizationParameters::NTuple{2, AbstractArray{<:Real,2}})
    minValues = normalizationParameters[1];
    maxValues = normalizationParameters[2];
    dataset .-= minValues;
    dataset ./= (maxValues .- minValues);
    # eliminate any atribute that do not add information
    dataset[:, vec(minValues.==maxValues)] .= 0;
    return dataset;
end;

function normalizeMinMax!(dataset::AbstractArray{<:Real,2})
    normalizeMinMax!(dataset , calculateMinMaxNormalizationParameters(dataset));
end;

function normalizeMinMax( dataset::AbstractArray{<:Real,2},      
                normalizationParameters::NTuple{2, AbstractArray{<:Real,2}}) 
    normalizeMinMax!(copy(dataset), normalizationParameters);
end;

function normalizeMinMax( dataset::AbstractArray{<:Real,2})
      normalizeMinMax!(copy(dataset), calculateMinMaxNormalizationParameters(dataset));
end;

function normalizeZeroMean!(dataset::AbstractArray{<:Real,2},      
                        normalizationParameters::NTuple{2, AbstractArray{<:Real,2}}) 
    avgValues = normalizationParameters[1];
    stdValues = normalizationParameters[2];
    dataset .-= avgValues;
    dataset ./= stdValues;
    # Remove any atribute that do not have information
    dataset[:, vec(stdValues.==0)] .= 0;
    return dataset; 
end;

function normalizeZeroMean!(dataset::AbstractArray{<:Real,2})
    normalizeZeroMean!(dataset , calculateZeroMeanNormalizationParameters(dataset));   
end;

function normalizeZeroMean( dataset::AbstractArray{<:Real,2},      
                            normalizationParameters::NTuple{2, AbstractArray{<:Real,2}})
    normalizeZeroMean!(copy(dataset), normalizationParameters);
end;

function normalizeZeroMean( dataset::AbstractArray{<:Real,2}) 
    normalizeZeroMean!(copy(dataset), calculateZeroMeanNormalizationParameters(dataset));
end;

function classifyOutputs(outputs::AbstractArray{<:Real,2}; 
                        threshold::Real=0.5) 
   numOutputs = size(outputs, 2);
    @assert(numOutputs!=2)
    if numOutputs==1
        return outputs.>=threshold;
    else
        # Look for the maximum value using the findmax funtion
        (_,indicesMaxEachInstance) = findmax(outputs, dims=2);
        # Set up then boolean matrix to everything false while max values aretrue.
        outputs = falses(size(outputs));
        outputs[indicesMaxEachInstance] .= true;
        # Defensive check if all patterns are in a single class
        @assert(all(sum(outputs, dims=2).==1));
        return outputs;
    end;
end;

function accuracy(outputs::AbstractArray{Bool,1}, targets::AbstractArray{Bool,1}) 
    mean(outputs.==targets);
end;

function accuracy(outputs::AbstractArray{<:Real,2}, targets::AbstractArray{Bool,2};
                threshold::Real=0.5)
    @assert(all(size(outputs).==size(targets)));
    if (size(targets,2)==1)
        return accuracy(outputs[:,1], targets[:,1]);
    else
        return accuracy(classifyOutputs(outputs; threshold=threshold), targets);
    end;
end;

function buildClassANN(numInputs::Int, topology::AbstractArray{<:Int,1}, numOutputs::Int;
                    transferFunctions::AbstractArray{<:Function,1}=fill(σ, length(topology))) 
    ann=Chain();
    numInputsLayer = numInputs;
    for numHiddenLayer in 1:length(topology)
        numNeurons = topology[numHiddenLayer];
        ann = Chain(ann..., Dense(numInputsLayer, numNeurons, transferFunctions[numHiddenLayer]));
        numInputsLayer = numNeurons;
    end;
    if (numOutputs == 1)
        ann = Chain(ann..., Dense(numInputsLayer, 1, σ));
    else
        ann = Chain(ann..., Dense(numInputsLayer, numOutputs, identity));
        ann = Chain(ann..., softmax);
    end;
    return ann;
end;

# %%
using Flux;

topology = [4, 3];

dataset = readdlm("iris.data",',');
train_ind, val_ind, test_ind = holdOut(size(dataset)[1], 0.2, 0.2);

training = dataset[train_ind,:];
validation = dataset[val_ind,:];
test = dataset[test_ind,:];

train_inputs = convert(Array{Float32,2}, training[:,1:4]);
train_targets = oneHotEncoding(training[:,5]);

val_inputs = convert(Array{Float32,2}, validation[:,1:4]);
val_targets = oneHotEncoding(validation[:,5]);

test_inputs = convert(Array{Float32,2}, test[:,1:4]);
test_targets = oneHotEncoding(test[:,5]);

# Normalization 
newInputs = normalizeMinMax(train_inputs);
@assert(all(minimum(newInputs, dims=1) .== 0));
@assert(all(maximum(newInputs, dims=1) .== 1));
#newInputs = normalizeZeroMean(inputs);
#@assert(all(abs.(mean(newInputs, dims=1))    .<= 1e-4));
#@assert(all(abs.(std( newInputs, dims=1)).-1 .<= 1e-4));

(ann, annTrainLosses, annValLosses, annTestLosses) = trainClassANN(topology, (train_inputs, train_targets), (val_inputs, val_targets), 
    (test_inputs, test_targets));
println(size(annTestLosses))
# plot(1:length(annTrainLosses), annTrainLosses,
#     xaxis = "Epoch", yaxis = "Loss value", title = "Train Loss",
#     marker = :square, color = :red, label = "Train")
# plot!(1:length(annValLosses), annValLosses,
#     xaxis = "Epoch", yaxis = "Loss value", title = "Validation Loss",
#     marker = :square, color = :blue, label = "Validation")
# plot!(1:length(annTestLosses), annTestLosses,
#     xaxis = "Epoch", yaxis = "Loss value", title = "Test Loss",
#     marker = :square, color = :green, label = "Test")
# Out:
# Epoch 0: train loss : 1.514913: validation loss : 1.2575513: test loss :1.5476588
# Epoch 1: train loss: 1.487155: validation loss :1.2396573: test loss :1.5217823
# Epoch 2: train loss: 1.4609362: validation loss :1.2228879: test loss :1.4968861
# Epoch 3: train loss: 1.4362216: validation loss :1.2075244: test loss :1.4734104
# Epoch 4: train loss: 1.4129473: validation loss :1.1935735: test loss :1.4513185
# Epoch 5: train loss: 1.3910098: validation loss :1.1810075: test loss :1.4305494
# Epoch 6: train loss: 1.3702935: validation loss :1.1697369: test loss :1.4109999
# Epoch 7: train loss: 1.3506912: validation loss :1.1596504: test loss :1.3925598
# Epoch 8: train loss: 1.3321074: validation loss :1.1506506: test loss :1.3751323
# Epoch 9: train loss: 1.3144574: validation loss :1.1426551: test loss :1.358637
# Epoch 10: train loss: 1.2976735: validation loss :1.1355973: test loss :1.3430095
# Epoch 11: train loss: 1.2817031: validation loss :1.1294258: test loss :1.3282021
# Epoch 12: train loss: 1.2665111: validation loss :1.1240996: test loss :1.3141801
# Epoch 13: train loss: 1.2520752: validation loss :1.1195831: test loss :1.300915
# Epoch 14: train loss: 1.2383846: validation loss :1.115837: test loss :1.2883805
# Epoch 15: train loss: 1.2254399: validation loss :1.1128147: test loss :1.2765466
# Epoch 16: train loss: 1.2132525: validation loss :1.1104597: test loss :1.265377
# Epoch 17: train loss: 1.2018473: validation loss :1.1087013: test loss :1.2548295
# Epoch 18: train loss: 1.1912508: validation loss :1.1074476: test loss :1.2448531
# Epoch 19: train loss: 1.1814811: validation loss :1.1065828: test loss :1.235391
# Epoch 20: train loss: 1.1725259: validation loss :1.105976: test loss :1.2263895
# Epoch 21: train loss: 1.164334: validation loss :1.1055077: test loss :1.2178108
# Epoch 22: train loss: 1.1568235: validation loss :1.1050985: test loss :1.2096413
# Epoch 23: train loss: 1.1499099: validation loss :1.1047153: test loss :1.2018858
# Epoch 24: train loss: 1.1435301: validation loss :1.1043535: test loss :1.1945492
# Epoch 25: train loss: 1.1376466: validation loss :1.1040131: test loss :1.1876259
# Epoch 26: train loss: 1.13224: validation loss :1.10369: test loss :1.1810997
# Epoch 27: train loss: 1.127301: validation loss :1.1033734: test loss :1.1749471
# Epoch 28: train loss: 1.1228225: validation loss :1.103053: test loss :1.1691424
# Epoch 29: train loss: 1.1187955: validation loss :1.1027253: test loss :1.163664
# Epoch 30: train loss: 1.1152055: validation loss :1.102396: test loss :1.1584967
# Epoch 31: train loss: 1.1120307: validation loss :1.1020832: test loss :1.1536351
# Epoch 32: train loss: 1.1092418: validation loss :1.1018143: test loss :1.1490813
# Epoch 33: train loss: 1.1068023: validation loss :1.1016228: test loss :1.1448436
# Epoch 34: train loss: 1.1046724: validation loss :1.101541: test loss :1.1409317
# Epoch 35: train loss: 1.1028085: validation loss :1.1015948: test loss :1.1373541
# Epoch 36: train loss: 1.1011695: validation loss :1.1018021: test loss :1.1341149
# Epoch 37: train loss: 1.0997175: validation loss :1.1021706: test loss :1.1312125
# Epoch 38: train loss: 1.098418: validation loss :1.1027004: test loss :1.1286409
# Epoch 39: train loss: 1.0972414: validation loss :1.103385: test loss :1.1263902
# Epoch 40: train loss: 1.0961627: validation loss :1.104216: test loss :1.124448
# Epoch 41: train loss: 1.0951606: validation loss :1.1051823: test loss :1.1228002
# Epoch 42: train loss: 1.0942161: validation loss :1.106272: test loss :1.1214329
# Epoch 43: train loss: 1.0933135: validation loss :1.1074748: test loss :1.1203313
# Epoch 44: train loss: 1.092439: validation loss :1.1087792: test loss :1.1194816
# Epoch 45: train loss: 1.0915805: validation loss :1.1101744: test loss :1.1188685
# Epoch 46: train loss: 1.090727: validation loss :1.1116496: test loss :1.1184776
# Epoch 47: train loss: 1.0898694: validation loss :1.113191: test loss :1.1182926
# Epoch 48: train loss: 1.0889984: validation loss :1.1147846: test loss :1.1182973
# Epoch 49: train loss: 1.088108: validation loss :1.1164135: test loss :1.118473
# Epoch 50: train loss: 1.08719: validation loss :1.1180584: test loss :1.1188004
# Epoch 51: train loss: 1.0862393: validation loss :1.119698: test loss :1.119259
# Epoch 52: train loss: 1.0852505: validation loss :1.1213098: test loss :1.119828
# Epoch 53: train loss: 1.0842181: validation loss :1.12287: test loss :1.1204864
# Epoch 54: train loss: 1.0831378: validation loss :1.1243572: test loss :1.1212143
# (55,)

# %%
#Develop here the corresponding code and/or in an external file
#You can load instead of copy and paste
#TODO
using Flux;

#Define the parameters
topology = [7, 3];

# Load the dataset
dataset = readdlm("iris.data",',');
train_ind, val_ind, test_ind = holdOut(size(dataset)[1], 0.15, 0.15);

training = dataset[train_ind,:];
validation = dataset[val_ind,:];
test = dataset[test_ind,:];

# Prepare the data
train_inputs = convert(Array{Float32,2}, training[:,1:4]);
train_targets = oneHotEncoding(training[:,5]);

val_inputs = convert(Array{Float32,2}, validation[:,1:4]);
val_targets = oneHotEncoding(validation[:,5]);

test_inputs = convert(Array{Float32,2}, test[:,1:4]);
test_targets = oneHotEncoding(test[:,5]);

# Normalization 
newInputs = normalizeMinMax(train_inputs);
@assert(all(minimum(newInputs, dims=1) .== 0));
@assert(all(maximum(newInputs, dims=1) .== 1));
# Standarization. Beware of the error done for using the meand and std they are not going to hit perfect 0 or 1
#newInputs = normalizeZeroMean(inputs);
#@assert(all(abs.(mean(newInputs, dims=1))    .<= 1e-4));
#@assert(all(abs.(std( newInputs, dims=1)).-1 .<= 1e-4));

# In this example, we use the MAX-MIN normalization

(ann, annTrainLosses, annValLosses, annTestLosses) = trainClassANN(topology, (train_inputs, train_targets), (val_inputs, val_targets), 
    (test_inputs, test_targets));
plot(1:length(annTrainLosses), annTrainLosses,
    xaxis = "Epoch", yaxis = "Loss value", title = "Train Loss",
    marker = :square, color = :red, label = "Train")
plot!(1:length(annValLosses), annValLosses,
    xaxis = "Epoch", yaxis = "Loss value", title = "Validation Loss",
    marker = :square, color = :blue, label = "Validation")
plot!(1:length(annTestLosses), annTestLosses,
    xaxis = "Epoch", yaxis = "Loss value", title = "Test Loss",
    marker = :square, color = :green, label = "Test")
# Out:
# Epoch 0: train loss : 1.1082537: validation loss : 1.0901345: test loss :1.0581754
# Epoch 1: train loss: 1.1003892: validation loss :1.0896502: test loss :1.0632409
# Epoch 2: train loss: 1.0936092: validation loss :1.090194: test loss :1.0689423
# Epoch 3: train loss: 1.0877455: validation loss :1.0913861: test loss :1.0748723
# Epoch 4: train loss: 1.0826492: validation loss :1.0931838: test loss :1.0809224
# Epoch 5: train loss: 1.078159: validation loss :1.095353: test loss :1.0867932
# Epoch 6: train loss: 1.0741019: validation loss :1.0975926: test loss :1.0921208
# Epoch 7: train loss: 1.0703096: validation loss :1.0996171: test loss :1.0965666
# Epoch 8: train loss: 1.0666336: validation loss :1.101194: test loss :1.0998778
# Epoch 9: train loss: 1.0629616: validation loss :1.1021596: test loss :1.1019156
# Epoch 10: train loss: 1.0592241: validation loss :1.1024143: test loss :1.1026411
# Epoch 11: train loss: 1.0553889: validation loss :1.101903: test loss :1.102081
# Epoch 12: train loss: 1.0514507: validation loss :1.1006042: test loss :1.1003017
# Epoch 13: train loss: 1.0474198: validation loss :1.0985214: test loss :1.097391
# Epoch 14: train loss: 1.04331: validation loss :1.0956796: test loss :1.0934422
# Epoch 15: train loss: 1.0391268: validation loss :1.0921192: test loss :1.0885398
# Epoch 16: train loss: 1.0348582: validation loss :1.0878901: test loss :1.0827473
# Epoch 17: train loss: 1.0304729: validation loss :1.083047: test loss :1.0761067
# Epoch 18: train loss: 1.0259298: validation loss :1.0776522: test loss :1.0686516
# Epoch 19: train loss: 1.0211918: validation loss :1.0717752: test loss :1.0604267
# Epoch 20: train loss: 1.0162325: validation loss :1.0654917: test loss :1.0514982
# Epoch 21: train loss: 1.0110372: validation loss :1.0588795: test loss :1.0419537
# Epoch 22: train loss: 1.0056: validation loss :1.0520153: test loss :1.0318973
# Epoch 23: train loss: 0.9999193: validation loss :1.0449693: test loss :1.0214418
# Epoch 24: train loss: 0.9939957: validation loss :1.037802: test loss :1.0107
# Epoch 25: train loss: 0.9878309: validation loss :1.0305607: test loss :0.99977744
# Epoch 26: train loss: 0.98142606: validation loss :1.0232785: test loss :0.98876697
# Epoch 27: train loss: 0.97478384: validation loss :1.0159745: test loss :0.97774684
# Epoch 28: train loss: 0.96790683: validation loss :1.0086557: test loss :0.96677846
# Epoch 29: train loss: 0.960799: validation loss :1.0013171: test loss :0.9559051
# Epoch 30: train loss: 0.9534647: validation loss :0.9939439: test loss :0.9451498
# Epoch 31: train loss: 0.94590837: validation loss :0.9865132: test loss :0.9345151
# Epoch 32: train loss: 0.93813384: validation loss :0.9789953: test loss :0.9239827
# Epoch 33: train loss: 0.93014336: validation loss :0.97135687: test loss :0.9135146
# Epoch 34: train loss: 0.9219368: validation loss :0.96356285: test loss :0.9030564
# Epoch 35: train loss: 0.9135111: validation loss :0.955579: test loss :0.8925415
# Epoch 36: train loss: 0.9048608: validation loss :0.94737417: test loss :0.8818977
# Epoch 37: train loss: 0.89597976: validation loss :0.9389232: test loss :0.87105435
# Epoch 38: train loss: 0.88686407: validation loss :0.9302091: test loss :0.8599504
# Epoch 39: train loss: 0.87751406: validation loss :0.9212248: test loss :0.8485428
# Epoch 40: train loss: 0.8679364: validation loss :0.9119732: test loss :0.83681005
# Epoch 41: train loss: 0.8581455: validation loss :0.9024686: test loss :0.8247558
# Epoch 42: train loss: 0.84816206: validation loss :0.8927332: test loss :0.8124072
# Epoch 43: train loss: 0.8380118: validation loss :0.8827954: test loss :0.79981166
# Epoch 44: train loss: 0.82772297: validation loss :0.8726855: test loss :0.7870285
# Epoch 45: train loss: 0.81732583: validation loss :0.8624328: test loss :0.77411574
# Epoch 46: train loss: 0.80685294: validation loss :0.8520662: test loss :0.761125
# Epoch 47: train loss: 0.7963376: validation loss :0.8416167: test loss :0.74810463
# Epoch 48: train loss: 0.7858141: validation loss :0.8311182: test loss :0.73510027
# Epoch 49: train loss: 0.77531666: validation loss :0.8206084: test loss :0.72215426
# Epoch 50: train loss: 0.7648777: validation loss :0.8101271: test loss :0.7093053
# Epoch 51: train loss: 0.754528: validation loss :0.7997159: test loss :0.69658786
# Epoch 52: train loss: 0.7442968: validation loss :0.7894167: test loss :0.6840339
# Epoch 53: train loss: 0.7342101: validation loss :0.77927023: test loss :0.6716717
# Epoch 54: train loss: 0.7242915: validation loss :0.7693151: test loss :0.659528
# Epoch 55: train loss: 0.71456254: validation loss :0.7595865: test loss :0.6476279
# Epoch 56: train loss: 0.70504177: validation loss :0.7501152: test loss :0.63599485
# Epoch 57: train loss: 0.69574547: validation loss :0.7409277: test loss :0.62465084
# Epoch 58: train loss: 0.68668723: validation loss :0.73204553: test loss :0.61361563
# Epoch 59: train loss: 0.67787737: validation loss :0.7234852: test loss :0.60290605
# Epoch 60: train loss: 0.66932327: validation loss :0.7152579: test loss :0.5925354
# Epoch 61: train loss: 0.6610294: validation loss :0.7073709: test loss :0.58251315
# Epoch 62: train loss: 0.6529972: validation loss :0.6998275: test loss :0.57284427
# Epoch 63: train loss: 0.64522576: validation loss :0.69262844: test loss :0.5635301
# Epoch 64: train loss: 0.6377125: validation loss :0.68577343: test loss :0.55456793
# Epoch 65: train loss: 0.63045335: validation loss :0.67926157: test loss :0.5459523
# Epoch 66: train loss: 0.6234432: validation loss :0.67309284: test loss :0.5376747
# Epoch 67: train loss: 0.6166756: validation loss :0.66726816: test loss :0.52972484
# Epoch 68: train loss: 0.6101439: validation loss :0.66179: test loss :0.5220909
# Epoch 69: train loss: 0.6038398: validation loss :0.65666187: test loss :0.51476
# Epoch 70: train loss: 0.59775466: validation loss :0.6518875: test loss :0.50771874
# Epoch 71: train loss: 0.5918784: validation loss :0.64747036: test loss :0.5009535
# Epoch 72: train loss: 0.5862005: validation loss :0.6434126: test loss :0.49445105
# Epoch 73: train loss: 0.580709: validation loss :0.63971424: test loss :0.48819828
# Epoch 74: train loss: 0.5753914: validation loss :0.63637316: test loss :0.48218292
# Epoch 75: train loss: 0.57023466: validation loss :0.63338417: test loss :0.47639287
# Epoch 76: train loss: 0.56522536: validation loss :0.6307406: test loss :0.47081643
# Epoch 77: train loss: 0.5603493: validation loss :0.62843376: test loss :0.46544218
# Epoch 78: train loss: 0.55559283: validation loss :0.62645483: test loss :0.4602582
# Epoch 79: train loss: 0.5509418: validation loss :0.6247957: test loss :0.45525208
# Epoch 80: train loss: 0.5463827: validation loss :0.62344944: test loss :0.4504112
# Epoch 81: train loss: 0.5419023: validation loss :0.62241066: test loss :0.44572246
# Epoch 82: train loss: 0.5374875: validation loss :0.6216746: test loss :0.44117284
# Epoch 83: train loss: 0.5331261: validation loss :0.6212366: test loss :0.43675017
# Epoch 84: train loss: 0.52880704: validation loss :0.6210902: test loss :0.43244338
# Epoch 85: train loss: 0.52451974: validation loss :0.6212268: test loss :0.42824346
# Epoch 86: train loss: 0.5202547: validation loss :0.6216357: test loss :0.42414302
# Epoch 87: train loss: 0.516004: validation loss :0.62230587: test loss :0.4201358
# Epoch 88: train loss: 0.5117606: validation loss :0.62322885: test loss :0.41621587
# Epoch 89: train loss: 0.5075189: validation loss :0.62439984: test loss :0.41237685
# Epoch 90: train loss: 0.5032746: validation loss :0.6258181: test loss :0.40861183
# Epoch 91: train loss: 0.49902445: validation loss :0.62748533: test loss :0.4049142
# Epoch 92: train loss: 0.4947662: validation loss :0.6294021: test loss :0.4012777
# Epoch 93: train loss: 0.49049854: validation loss :0.63156635: test loss :0.39769775
# Epoch 94: train loss: 0.48622072: validation loss :0.63397086: test loss :0.39417154
# Epoch 95: train loss: 0.48193282: validation loss :0.6366042: test loss :0.39069757
# Epoch 96: train loss: 0.47763503: validation loss :0.63945276: test loss :0.38727516
# Epoch 97: train loss: 0.47332796: validation loss :0.642504: test loss :0.38390267
# Epoch 98: train loss: 0.46901223: validation loss :0.64575046: test loss :0.3805766
# Epoch 99: train loss: 0.46468872: validation loss :0.64919114: test loss :0.37729043
# Epoch 100: train loss: 0.46035865: validation loss :0.6528313: test loss :0.37403503
# Epoch 101: train loss: 0.45602328: validation loss :0.65667754: test loss :0.37080008
# Epoch 102: train loss: 0.4516839: validation loss :0.6607332: test loss :0.36757627
# Epoch 103: train loss: 0.44734263: validation loss :0.6649933: test loss :0.3643571
# Epoch 104: train loss: 0.44300124: validation loss :0.66944325: test loss :0.36114016

# %%
#Develop here the corresponding code and/or in an external file
#You can load instead of copy and paste
#TODO
using Flux;

#Define the parameters
topology = [2, 3];

# Load the dataset
dataset = readdlm("iris.data",',');
train_ind, val_ind, test_ind = holdOut(size(dataset)[1], 0.1, 0.15);

training = dataset[train_ind,:];
validation = dataset[val_ind,:];
test = dataset[test_ind,:];

# Prepare the data
train_inputs = convert(Array{Float32,2}, training[:,1:4]);
train_targets = oneHotEncoding(training[:,5]);

val_inputs = convert(Array{Float32,2}, validation[:,1:4]);
val_targets = oneHotEncoding(validation[:,5]);

test_inputs = convert(Array{Float32,2}, test[:,1:4]);
test_targets = oneHotEncoding(test[:,5]);

# Normalization 
newInputs = normalizeMinMax(train_inputs);
@assert(all(minimum(newInputs, dims=1) .== 0));
@assert(all(maximum(newInputs, dims=1) .== 1));
# Standarization. Beware of the error done for using the meand and std they are not going to hit perfect 0 or 1
#newInputs = normalizeZeroMean(inputs);
#@assert(all(abs.(mean(newInputs, dims=1))    .<= 1e-4));
#@assert(all(abs.(std( newInputs, dims=1)).-1 .<= 1e-4));

# In this example, we use the MAX-MIN normalization

(ann, annTrainLosses, annValLosses, annTestLosses) = trainClassANN(topology, (train_inputs, train_targets), (val_inputs, val_targets), 
    (test_inputs, test_targets));
plot(1:length(annTrainLosses), annTrainLosses,
    xaxis = "Epoch", yaxis = "Loss value", title = "Train Loss",
    marker = :square, color = :red, label = "Train")
plot!(1:length(annValLosses), annValLosses,
    xaxis = "Epoch", yaxis = "Loss value", title = "Validation Loss",
    marker = :square, color = :blue, label = "Validation")
plot!(1:length(annTestLosses), annTestLosses,
    xaxis = "Epoch", yaxis = "Loss value", title = "Test Loss",
    marker = :square, color = :green, label = "Test")
# Out:
# Epoch 0: train loss : 1.1179254: validation loss : 1.1470873: test loss :1.1189312
# Epoch 1: train loss: 1.1125238: validation loss :1.1396267: test loss :1.1166639
# Epoch 2: train loss: 1.1081952: validation loss :1.1331892: test loss :1.1154368
# Epoch 3: train loss: 1.1049119: validation loss :1.1275619: test loss :1.1148674
# Epoch 4: train loss: 1.1025531: validation loss :1.122443: test loss :1.1144474
# Epoch 5: train loss: 1.1009783: validation loss :1.1177164: test loss :1.113917
# Epoch 6: train loss: 1.1000557: validation loss :1.1133753: test loss :1.1131573
# Epoch 7: train loss: 1.0996435: validation loss :1.109409: test loss :1.1120663
# Epoch 8: train loss: 1.0995795: validation loss :1.1057645: test loss :1.1105435
# Epoch 9: train loss: 1.0997: validation loss :1.1023831: test loss :1.1085479
# Epoch 10: train loss: 1.0998752: validation loss :1.099249: test loss :1.1061352
# Epoch 11: train loss: 1.1000203: validation loss :1.0963935: test loss :1.1034333
# Epoch 12: train loss: 1.1000894: validation loss :1.0938762: test loss :1.1006054
# Epoch 13: train loss: 1.1000638: validation loss :1.0917665: test loss :1.0978277
# Epoch 14: train loss: 1.0999397: validation loss :1.0901258: test loss :1.0952666
# Epoch 15: train loss: 1.0997208: validation loss :1.0889921: test loss :1.0930609
# Epoch 16: train loss: 1.0994164: validation loss :1.0883719: test loss :1.0913035
# Epoch 17: train loss: 1.0990417: validation loss :1.0882387: test loss :1.0900394
# Epoch 18: train loss: 1.0986162: validation loss :1.088541: test loss :1.0892727
# Epoch 19: train loss: 1.0981613: validation loss :1.089211: test loss :1.0889788
# Epoch 20: train loss: 1.0976962: validation loss :1.0901712: test loss :1.0891131
# Epoch 21: train loss: 1.0972341: validation loss :1.0913388: test loss :1.0896182
# Epoch 22: train loss: 1.0967829: validation loss :1.0926287: test loss :1.0904274
# Epoch 23: train loss: 1.0963429: validation loss :1.093954: test loss :1.091466
# Epoch 24: train loss: 1.0959082: validation loss :1.0952277: test loss :1.0926554
# Epoch 25: train loss: 1.0954667: validation loss :1.096365: test loss :1.0939139
# Epoch 26: train loss: 1.0950023: validation loss :1.0972842: test loss :1.0951613
# Epoch 27: train loss: 1.0944946: validation loss :1.0979095: test loss :1.0963229
# Epoch 28: train loss: 1.093921: validation loss :1.0981736: test loss :1.0973336
# Epoch 29: train loss: 1.093258: validation loss :1.0980203: test loss :1.098143
# Epoch 30: train loss: 1.0924827: validation loss :1.0974056: test loss :1.0987192
# Epoch 31: train loss: 1.091573: validation loss :1.0962973: test loss :1.0990492
# Epoch 32: train loss: 1.0905076: validation loss :1.0946751: test loss :1.09914
# Epoch 33: train loss: 1.0892667: validation loss :1.0925256: test loss :1.0990169
# Epoch 34: train loss: 1.087829: validation loss :1.089841: test loss :1.0987203
# Epoch 35: train loss: 1.0861739: validation loss :1.086616: test loss :1.0983038
# Epoch 36: train loss: 1.0842793: validation loss :1.0828445: test loss :1.0978303
# Epoch 37: train loss: 1.0821232: validation loss :1.0785207: test loss :1.0973696
# Epoch 38: train loss: 1.079685: validation loss :1.0736411: test loss :1.096994
# Epoch 39: train loss: 1.0769476: validation loss :1.068209: test loss :1.0967752
# Epoch 40: train loss: 1.0738962: validation loss :1.0622468: test loss :1.0967741
# Epoch 41: train loss: 1.0705141: validation loss :1.0557992: test loss :1.0970309
# Epoch 42: train loss: 1.0667785: validation loss :1.0489117: test loss :1.0975678
# Epoch 43: train loss: 1.0626729: validation loss :1.0416007: test loss :1.0984123
# Epoch 44: train loss: 1.058195: validation loss :1.0338737: test loss :1.0995995
# Epoch 45: train loss: 1.0533556: validation loss :1.025752: test loss :1.101162
# Epoch 46: train loss: 1.0481739: validation loss :1.0172743: test loss :1.1031241
# Epoch 47: train loss: 1.0426763: validation loss :1.0084965: test loss :1.1055005
# Epoch 48: train loss: 1.0368912: validation loss :0.9994893: test loss :1.1082938
# Epoch 49: train loss: 1.0308465: validation loss :0.99033356: test loss :1.1114929
# Epoch 50: train loss: 1.0245631: validation loss :0.9811155: test loss :1.115072
# Epoch 51: train loss: 1.0180537: validation loss :0.9719214: test loss :1.1189922
# Epoch 52: train loss: 1.011319: validation loss :0.9628289: test loss :1.1232045
# Epoch 53: train loss: 1.0043546: validation loss :0.95390064: test loss :1.1276578
# Epoch 54: train loss: 0.9971561: validation loss :0.9451776: test loss :1.1323097
# Epoch 55: train loss: 0.98972857: validation loss :0.93667537: test loss :1.1371343
# Epoch 56: train loss: 0.9820916: validation loss :0.9283836: test loss :1.1421257
# Epoch 57: train loss: 0.97427595: validation loss :0.9202641: test loss :1.1472958
# Epoch 58: train loss: 0.9663168: validation loss :0.9122534: test loss :1.1526686
# Epoch 59: train loss: 0.95824295: validation loss :0.90426373: test loss :1.158272
# Epoch 60: train loss: 0.9500713: validation loss :0.89619184: test loss :1.1641349
# Epoch 61: train loss: 0.941805: validation loss :0.88793004: test loss :1.1702807
# Epoch 62: train loss: 0.9334385: validation loss :0.879385: test loss :1.1767263
# Epoch 63: train loss: 0.924965: validation loss :0.8704952: test loss :1.1834801
# Epoch 64: train loss: 0.9163855: validation loss :0.86124086: test loss :1.1905416
# Epoch 65: train loss: 0.90771043: validation loss :0.8516479: test loss :1.1979002
# Epoch 66: train loss: 0.8989595: validation loss :0.84178007: test loss :1.2055368
# Epoch 67: train loss: 0.89015657: validation loss :0.83172524: test loss :1.2134243
# Epoch 68: train loss: 0.8813235: validation loss :0.82158107: test loss :1.2215291
# Epoch 69: train loss: 0.87247664: validation loss :0.8114394: test loss :1.2298158
# Epoch 70: train loss: 0.86362636: validation loss :0.80137694: test loss :1.2382519
# Epoch 71: train loss: 0.8547794: validation loss :0.79144764: test loss :1.2468144
# Epoch 72: train loss: 0.8459427: validation loss :0.78168195: test loss :1.2554948
# Epoch 73: train loss: 0.8371259: validation loss :0.77208793: test loss :1.2643026
# Epoch 74: train loss: 0.82834244: validation loss :0.7626571: test loss :1.2732623
# Epoch 75: train loss: 0.81960744: validation loss :0.7533679: test loss :1.2824115
# Epoch 76: train loss: 0.81093556: validation loss :0.74419314: test loss :1.291795
# Epoch 77: train loss: 0.80233914: validation loss :0.73510635: test loss :1.3014591
# Epoch 78: train loss: 0.79382896: validation loss :0.72608614: test loss :1.3114457
# Epoch 79: train loss: 0.7854138: validation loss :0.7171226: test loss :1.321789
# Epoch 80: train loss: 0.77710253: validation loss :0.70821935: test loss :1.3325114
# Epoch 81: train loss: 0.7689042: validation loss :0.6993917: test loss :1.3436233
# Epoch 82: train loss: 0.76082796: validation loss :0.6906653: test loss :1.3551227
# Epoch 83: train loss: 0.7528833: validation loss :0.6820711: test loss :1.3669981
# Epoch 84: train loss: 0.7450782: validation loss :0.6736405: test loss :1.3792307
# Epoch 85: train loss: 0.7374195: validation loss :0.665402: test loss :1.3917959
# Epoch 86: train loss: 0.72991264: validation loss :0.65737766: test loss :1.4046685
# Epoch 87: train loss: 0.7225617: validation loss :0.6495826: test loss :1.4178226
# Epoch 88: train loss: 0.71537113: validation loss :0.6420243: test loss :1.4312359
# Epoch 89: train loss: 0.7083441: validation loss :0.63470316: test loss :1.4448881
# Epoch 90: train loss: 0.7014842: validation loss :0.6276143: test loss :1.4587626
# Epoch 91: train loss: 0.6947951: validation loss :0.6207492: test loss :1.4728448
# Epoch 92: train loss: 0.6882792: validation loss :0.61409646: test loss :1.487122
# Epoch 93: train loss: 0.6819386: validation loss :0.6076448: test loss :1.5015818
# Epoch 94: train loss: 0.675774: validation loss :0.60138285: test loss :1.5162107
# Epoch 95: train loss: 0.66978556: validation loss :0.59530085: test loss :1.5309947
# Epoch 96: train loss: 0.6639728: validation loss :0.58939147: test loss :1.5459177
# Epoch 97: train loss: 0.6583346: validation loss :0.58364946: test loss :1.5609615
# Epoch 98: train loss: 0.6528691: validation loss :0.57807165: test loss :1.5761068
# Epoch 99: train loss: 0.6475746: validation loss :0.57265705: test loss :1.5913329
# Epoch 100: train loss: 0.6424492: validation loss :0.5674054: test loss :1.6066185
# Epoch 101: train loss: 0.6374901: validation loss :0.5623174: test loss :1.6219429
# Epoch 102: train loss: 0.63269454: validation loss :0.55739313: test loss :1.6372864
# Epoch 103: train loss: 0.6280595: validation loss :0.5526328: test loss :1.6526312
# Epoch 104: train loss: 0.6235818: validation loss :0.54803556: test loss :1.6679611
# Epoch 105: train loss: 0.6192576: validation loss :0.5435996: test loss :1.6832625
# Epoch 106: train loss: 0.61508363: validation loss :0.53932273: test loss :1.6985247
# Epoch 107: train loss: 0.61105525: validation loss :0.53520125: test loss :1.7137387
# Epoch 108: train loss: 0.6071691: validation loss :0.53123134: test loss :1.7288984
# Epoch 109: train loss: 0.6034209: validation loss :0.5274086: test loss :1.7439985
# Epoch 110: train loss: 0.5998067: validation loss :0.52372813: test loss :1.7590357
# Epoch 111: train loss: 0.59632224: validation loss :0.52018493: test loss :1.7740074
# Epoch 112: train loss: 0.5929635: validation loss :0.5167741: test loss :1.7889111
# Epoch 113: train loss: 0.5897264: validation loss :0.5134906: test loss :1.8037455
# Epoch 114: train loss: 0.5866067: validation loss :0.5103297: test loss :1.8185078
# Epoch 115: train loss: 0.5836006: validation loss :0.5072867: test loss :1.8331963
# Epoch 116: train loss: 0.5807036: validation loss :0.5043571: test loss :1.8478076
# Epoch 117: train loss: 0.57791203: validation loss :0.5015368: test loss :1.8623387
# Epoch 118: train loss: 0.5752219: validation loss :0.49882168: test loss :1.8767853
# Epoch 119: train loss: 0.5726295: validation loss :0.49620777: test loss :1.8911434
# Epoch 120: train loss: 0.570131: validation loss :0.4936913: test loss :1.9054085
# Epoch 121: train loss: 0.56772286: validation loss :0.49126872: test loss :1.9195751
# Epoch 122: train loss: 0.5654013: validation loss :0.48893628: test loss :1.9336386
# Epoch 123: train loss: 0.56316334: validation loss :0.48669046: test loss :1.9475937
# Epoch 124: train loss: 0.5610052: validation loss :0.48452777: test loss :1.9614365
# Epoch 125: train loss: 0.5589241: validation loss :0.48244494: test loss :1.9751618
# Epoch 126: train loss: 0.5569167: validation loss :0.4804385: test loss :1.9887663
# Epoch 127: train loss: 0.5549799: validation loss :0.47850537: test loss :2.0022464
# Epoch 128: train loss: 0.553111: validation loss :0.47664246: test loss :2.0156002
# Epoch 129: train loss: 0.5513072: validation loss :0.47484648: test loss :2.0288246
# Epoch 130: train loss: 0.54956573: validation loss :0.4731149: test loss :2.0419188
# Epoch 131: train loss: 0.547884: validation loss :0.4714446: test loss :2.0548816
# Epoch 132: train loss: 0.5462596: validation loss :0.46983343: test loss :2.0677133
# Epoch 133: train loss: 0.54469013: validation loss :0.4682785: test loss :2.0804133
# Epoch 134: train loss: 0.54317325: validation loss :0.46677783: test loss :2.0929837
# Epoch 135: train loss: 0.5417067: validation loss :0.4653292: test loss :2.1054242
# Epoch 136: train loss: 0.5402886: validation loss :0.46393046: test loss :2.1177363
# Epoch 137: train loss: 0.53891695: validation loss :0.4625796: test loss :2.1299224
# Epoch 138: train loss: 0.53758943: validation loss :0.46127513: test loss :2.1419835
# Epoch 139: train loss: 0.53630465: validation loss :0.4600152: test loss :2.1539216
# Epoch 140: train loss: 0.53506076: validation loss :0.458798: test loss :2.1657386
# Epoch 141: train loss: 0.5338556: validation loss :0.45762226: test loss :2.177436
# Epoch 142: train loss: 0.53268814: validation loss :0.45648614: test loss :2.189016
# Epoch 143: train loss: 0.5315565: validation loss :0.45538852: test loss :2.20048
# Epoch 144: train loss: 0.5304593: validation loss :0.45432758: test loss :2.2118297
# Epoch 145: train loss: 0.52939504: validation loss :0.4533024: test loss :2.223067
# Epoch 146: train loss: 0.5283624: validation loss :0.45231152: test loss :2.2341926
# Epoch 147: train loss: 0.52735996: validation loss :0.45135355: test loss :2.2452083
# Epoch 148: train loss: 0.5263867: validation loss :0.45042735: test loss :2.2561157
# Epoch 149: train loss: 0.5254412: validation loss :0.4495317: test loss :2.2669158
# Epoch 150: train loss: 0.5245225: validation loss :0.44866547: test loss :2.2776103
# Epoch 151: train loss: 0.5236293: validation loss :0.44782764: test loss :2.2882
# Epoch 152: train loss: 0.5227607: validation loss :0.447017: test loss :2.2986875
# Epoch 153: train loss: 0.52191556: validation loss :0.44623283: test loss :2.309073
# Epoch 154: train loss: 0.52109295: validation loss :0.44547412: test loss :2.3193586
# Epoch 155: train loss: 0.5202919: validation loss :0.44474006: test loss :2.3295465
# Epoch 156: train loss: 0.51951176: validation loss :0.4440299: test loss :2.3396378
# Epoch 157: train loss: 0.51875126: validation loss :0.4433428: test loss :2.3496344
# Epoch 158: train loss: 0.51800984: validation loss :0.44267833: test loss :2.3595388
# Epoch 159: train loss: 0.51728666: validation loss :0.4420358: test loss :2.3693528
# Epoch 160: train loss: 0.51658076: validation loss :0.44141465: test loss :2.3790784
# Epoch 161: train loss: 0.51589155: validation loss :0.44081455: test loss :2.3887174
# Epoch 162: train loss: 0.5152184: validation loss :0.44023496: test loss :2.3982725
# Epoch 163: train loss: 0.5145603: validation loss :0.43967572: test loss :2.4077458
# Epoch 164: train loss: 0.51391685: validation loss :0.43913642: test loss :2.4171393
# Epoch 165: train loss: 0.5132872: validation loss :0.43861657: test loss :2.426455
# Epoch 166: train loss: 0.5126707: validation loss :0.43811622: test loss :2.435695
# Epoch 167: train loss: 0.5120669: validation loss :0.43763515: test loss :2.4448612
# Epoch 168: train loss: 0.5114748: validation loss :0.43717313: test loss :2.4539557
# Epoch 169: train loss: 0.51089406: validation loss :0.4367301: test loss :2.4629803
# Epoch 170: train loss: 0.51032406: validation loss :0.43630603: test loss :2.4719367
# Epoch 171: train loss: 0.50976396: validation loss :0.4359009: test loss :2.4808266
# Epoch 172: train loss: 0.50921327: validation loss :0.4355148: test loss :2.4896514
# Epoch 173: train loss: 0.5086714: validation loss :0.43514776: test loss :2.498413
# Epoch 174: train loss: 0.50813764: validation loss :0.43480003: test loss :2.5071125
# Epoch 175: train loss: 0.50761145: validation loss :0.43447185: test loss :2.515751
# Epoch 176: train loss: 0.507092: validation loss :0.43416363: test loss :2.5243301
# Epoch 177: train loss: 0.50657874: validation loss :0.4338758: test loss :2.5328505
# Epoch 178: train loss: 0.5060709: validation loss :0.43360895: test loss :2.541314
# Epoch 179: train loss: 0.50556785: validation loss :0.433364: test loss :2.5497203
# Epoch 180: train loss: 0.50506866: validation loss :0.43314138: test loss :2.5580716
# Epoch 181: train loss: 0.5045727: validation loss :0.43294248: test loss :2.5663679
# Epoch 182: train loss: 0.5040789: validation loss :0.43276837: test loss :2.5746102
# Epoch 183: train loss: 0.50358653: validation loss :0.43262064: test loss :2.5827987
# Epoch 184: train loss: 0.50309455: validation loss :0.43250084: test loss :2.5909338
# Epoch 185: train loss: 0.50260174: validation loss :0.43241104: test loss :2.5990157
# Epoch 186: train loss: 0.5021072: validation loss :0.43235338: test loss :2.607044
# Epoch 187: train loss: 0.50160927: validation loss :0.43233055: test loss :2.6150184
# Epoch 188: train loss: 0.5011068: validation loss :0.4323456: test loss :2.6229382
# Epoch 189: train loss: 0.5005983: validation loss :0.4324021: test loss :2.6308014
# Epoch 190: train loss: 0.5000821: validation loss :0.43250412: test loss :2.6386073
# Epoch 191: train loss: 0.49955612: validation loss :0.43265617: test loss :2.6463532
# Epoch 192: train loss: 0.4990184: validation loss :0.43286377: test loss :2.654036
# Epoch 193: train loss: 0.49846667: validation loss :0.43313292: test loss :2.661653
# Epoch 194: train loss: 0.4978984: validation loss :0.43347082: test loss :2.6691988
# Epoch 195: train loss: 0.4973107: validation loss :0.43388546: test loss :2.676669
# Epoch 196: train loss: 0.49670073: validation loss :0.4343859: test loss :2.6840568
# Epoch 197: train loss: 0.49606487: validation loss :0.4349826: test loss :2.6913567
# Epoch 198: train loss: 0.49539953: validation loss :0.43568695: test loss :2.6985583
# Epoch 199: train loss: 0.4947007: validation loss :0.43651187: test loss :2.7056546
# Epoch 200: train loss: 0.49396378: validation loss :0.4374713: test loss :2.7126343
# Epoch 201: train loss: 0.4931837: validation loss :0.4385802: test loss :2.7194867
# Epoch 202: train loss: 0.49235532: validation loss :0.43985447: test loss :2.7261999
# Epoch 203: train loss: 0.4914718: validation loss :0.4413106: test loss :2.7327619
# Epoch 204: train loss: 0.49052623: validation loss :0.44296503: test loss :2.7391572
# Epoch 205: train loss: 0.48951012: validation loss :0.4448342: test loss :2.745372
# Epoch 206: train loss: 0.48841348: validation loss :0.44693425: test loss :2.7513862
# Epoch 207: train loss: 0.4872243: validation loss :0.44928184: test loss :2.7571752

# %%
#Develop here the corresponding code and/or in an external file
#You can load instead of copy and paste
#TODO
using Flux;

#Define the parameters
topology = [4, 3];

# Load the dataset
dataset = readdlm("iris.data",',');
train_ind, val_ind, test_ind = holdOut(size(dataset)[1], 0.4, 0.2);

training = dataset[train_ind,:];
validation = dataset[val_ind,:];
test = dataset[test_ind,:];

# Prepare the data
train_inputs = convert(Array{Float32,2}, training[:,1:4]);
train_targets = oneHotEncoding(training[:,5]);

val_inputs = convert(Array{Float32,2}, validation[:,1:4]);
val_targets = oneHotEncoding(validation[:,5]);

test_inputs = convert(Array{Float32,2}, test[:,1:4]);
test_targets = oneHotEncoding(test[:,5]);

# Normalization 
newInputs = normalizeMinMax(train_inputs);
@assert(all(minimum(newInputs, dims=1) .== 0));
@assert(all(maximum(newInputs, dims=1) .== 1));
# Standarization. Beware of the error done for using the meand and std they are not going to hit perfect 0 or 1
#newInputs = normalizeZeroMean(inputs);
#@assert(all(abs.(mean(newInputs, dims=1))    .<= 1e-4));
#@assert(all(abs.(std( newInputs, dims=1)).-1 .<= 1e-4));

# In this example, we use the MAX-MIN normalization

(ann, annTrainLosses, annValLosses, annTestLosses) = trainClassANN(topology, (train_inputs, train_targets), (val_inputs, val_targets), 
    (test_inputs, test_targets));
plot(1:length(annTrainLosses), annTrainLosses,
    xaxis = "Epoch", yaxis = "Loss value", title = "Train Loss",
    marker = :square, color = :red, label = "Train")
plot!(1:length(annValLosses), annValLosses,
    xaxis = "Epoch", yaxis = "Loss value", title = "Validation Loss",
    marker = :square, color = :blue, label = "Validation")
plot!(1:length(annTestLosses), annTestLosses,
    xaxis = "Epoch", yaxis = "Loss value", title = "Test Loss",
    marker = :square, color = :green, label = "Test")
# Out:
# Epoch 0: train loss : 1.1014372: validation loss : 1.217352: test loss :1.2691505
# Epoch 1: train loss: 1.0919311: validation loss :1.2035242: test loss :1.2544502
# Epoch 2: train loss: 1.0838493: validation loss :1.1911478: test loss :1.2408684
# Epoch 3: train loss: 1.0771688: validation loss :1.1801791: test loss :1.2284944
# Epoch 4: train loss: 1.0717969: validation loss :1.1704884: test loss :1.2174188
# Epoch 5: train loss: 1.0675724: validation loss :1.1618534: test loss :1.2076538
# Epoch 6: train loss: 1.0642843: validation loss :1.1540157: test loss :1.1991435
# Epoch 7: train loss: 1.0617032: validation loss :1.146761: test loss :1.1918184
# Epoch 8: train loss: 1.0596136: validation loss :1.1399585: test loss :1.1856214
# Epoch 9: train loss: 1.0578312: validation loss :1.1335369: test loss :1.1805023
# Epoch 10: train loss: 1.05621: validation loss :1.127455: test loss :1.1764092
# Epoch 11: train loss: 1.0546404: validation loss :1.1216863: test loss :1.1732821
# Epoch 12: train loss: 1.0530452: validation loss :1.1162134: test loss :1.17106
# Epoch 13: train loss: 1.0513709: validation loss :1.1110249: test loss :1.1696845
# Epoch 14: train loss: 1.0495838: validation loss :1.1061133: test loss :1.1691024
# Epoch 15: train loss: 1.0476635: validation loss :1.1014739: test loss :1.169264
# Epoch 16: train loss: 1.0456005: validation loss :1.0971024: test loss :1.1701207
# Epoch 17: train loss: 1.0433931: validation loss :1.0929955: test loss :1.171625
# Epoch 18: train loss: 1.0410435: validation loss :1.0891485: test loss :1.1737297
# Epoch 19: train loss: 1.0385562: validation loss :1.0855535: test loss :1.1763864
# Epoch 20: train loss: 1.0359365: validation loss :1.0821964: test loss :1.1795477
# Epoch 21: train loss: 1.033189: validation loss :1.0790547: test loss :1.1831664
# Epoch 22: train loss: 1.0303175: validation loss :1.0760972: test loss :1.187197
# Epoch 23: train loss: 1.0273226: validation loss :1.073282: test loss :1.1915966
# Epoch 24: train loss: 1.0242031: validation loss :1.0705569: test loss :1.1963259
# Epoch 25: train loss: 1.0209535: validation loss :1.0678619: test loss :1.2013496
# Epoch 26: train loss: 1.017565: validation loss :1.0651317: test loss :1.2066363
# Epoch 27: train loss: 1.0140266: validation loss :1.0622973: test loss :1.2121586
# Epoch 28: train loss: 1.0103253: validation loss :1.0592926: test loss :1.217892
# Epoch 29: train loss: 1.0064497: validation loss :1.0560563: test loss :1.2238168
# Epoch 30: train loss: 1.0023894: validation loss :1.0525361: test loss :1.2299148
# Epoch 31: train loss: 0.9981372: validation loss :1.0486891: test loss :1.2361743
# Epoch 32: train loss: 0.99368805: validation loss :1.0444832: test loss :1.2425864
# Epoch 33: train loss: 0.98904085: validation loss :1.0398962: test loss :1.2491415
# Epoch 34: train loss: 0.9841973: validation loss :1.034917: test loss :1.2558339
# Epoch 35: train loss: 0.9791619: validation loss :1.0295444: test loss :1.2626605
# Epoch 36: train loss: 0.9739417: validation loss :1.0237871: test loss :1.26962
# Epoch 37: train loss: 0.96854526: validation loss :1.0176648: test loss :1.2767162
# Epoch 38: train loss: 0.9629819: validation loss :1.0112057: test loss :1.2839643
# Epoch 39: train loss: 0.9572562: validation loss :1.0044467: test loss :1.2914071
# Epoch 40: train loss: 0.9513624: validation loss :0.99742466: test loss :1.2991276
# Epoch 41: train loss: 0.9452889: validation loss :0.9901667: test loss :1.3072112
# Epoch 42: train loss: 0.9390307: validation loss :0.98269117: test loss :1.3157089
# Epoch 43: train loss: 0.9325913: validation loss :0.9750159: test loss :1.3246421
# Epoch 44: train loss: 0.92598385: validation loss :0.9671609: test loss :1.3340167
# Epoch 45: train loss: 0.9192259: validation loss :0.95914894: test loss :1.3438283
# Epoch 46: train loss: 0.91234004: validation loss :0.95100385: test loss :1.3540659
# Epoch 47: train loss: 0.9053512: validation loss :0.94275105: test loss :1.364714
# Epoch 48: train loss: 0.898284: validation loss :0.93441415: test loss :1.3757571
# Epoch 49: train loss: 0.891161: validation loss :0.92601514: test loss :1.3871821
# Epoch 50: train loss: 0.8840015: validation loss :0.9175736: test loss :1.3989801
# Epoch 51: train loss: 0.8768203: validation loss :0.90910524: test loss :1.4111507
# Epoch 52: train loss: 0.86962837: validation loss :0.9006235: test loss :1.4237001
# Epoch 53: train loss: 0.862433: validation loss :0.89213824: test loss :1.4366412
# Epoch 54: train loss: 0.85523885: validation loss :0.8836566: test loss :1.4499894
# Epoch 55: train loss: 0.848051: validation loss :0.87518436: test loss :1.4637597
# Epoch 56: train loss: 0.84087384: validation loss :0.8667266: test loss :1.4779587
# Epoch 57: train loss: 0.8337145: validation loss :0.8582874: test loss :1.4925814
# Epoch 58: train loss: 0.8265828: validation loss :0.84987193: test loss :1.5076072
# Epoch 59: train loss: 0.81949: validation loss :0.8414859: test loss :1.5229987
# Epoch 60: train loss: 0.812449: validation loss :0.83313614: test loss :1.5387034
# Epoch 61: train loss: 0.8054731: validation loss :0.8248299: test loss :1.5546578
# Epoch 62: train loss: 0.7985747: validation loss :0.8165751: test loss :1.5707932
# Epoch 63: train loss: 0.79176414: validation loss :0.8083802: test loss :1.5870413
# Epoch 64: train loss: 0.7850502: validation loss :0.80025357: test loss :1.6033385
# Epoch 65: train loss: 0.778439: validation loss :0.79220384: test loss :1.6196309
# Epoch 66: train loss: 0.7719347: validation loss :0.78424066: test loss :1.6358757
# Epoch 67: train loss: 0.76554066: validation loss :0.77637285: test loss :1.6520429
# Epoch 68: train loss: 0.7592592: validation loss :0.7686107: test loss :1.6681129
# Epoch 69: train loss: 0.7530925: validation loss :0.76096404: test loss :1.6840774
# Epoch 70: train loss: 0.74704266: validation loss :0.75344324: test loss :1.6999358
# Epoch 71: train loss: 0.7411107: validation loss :0.746058: test loss :1.7156931
# Epoch 72: train loss: 0.7352991: validation loss :0.7388175: test loss :1.731358
# Epoch 73: train loss: 0.7296094: validation loss :0.7317298: test loss :1.7469422
# Epoch 74: train loss: 0.724042: validation loss :0.72480196: test loss :1.7624559
# Epoch 75: train loss: 0.71859753: validation loss :0.7180399: test loss :1.7779101
# Epoch 76: train loss: 0.7132765: validation loss :0.7114481: test loss :1.7933117
# Epoch 77: train loss: 0.7080778: validation loss :0.7050305: test loss :1.8086658
# Epoch 78: train loss: 0.7030009: validation loss :0.6987901: test loss :1.823973
# Epoch 79: train loss: 0.6980434: validation loss :0.69272953: test loss :1.8392311
# Epoch 80: train loss: 0.6932036: validation loss :0.68685156: test loss :1.8544332
# Epoch 81: train loss: 0.6884793: validation loss :0.68115866: test loss :1.8695701
# Epoch 82: train loss: 0.6838671: validation loss :0.67565393: test loss :1.8846296
# Epoch 83: train loss: 0.67936397: validation loss :0.67034084: test loss :1.8995962
# Epoch 84: train loss: 0.67496663: validation loss :0.6652228: test loss :1.9144559
# Epoch 85: train loss: 0.6706711: validation loss :0.6603042: test loss :1.929192
# Epoch 86: train loss: 0.66647345: validation loss :0.6555893: test loss :1.9437903
# Epoch 87: train loss: 0.66236943: validation loss :0.6510828: test loss :1.958236
# Epoch 88: train loss: 0.65835506: validation loss :0.6467893: test loss :1.9725188
# Epoch 89: train loss: 0.6544253: validation loss :0.64271325: test loss :1.9866282
# Epoch 90: train loss: 0.650576: validation loss :0.63885957: test loss :2.0005577
# Epoch 91: train loss: 0.6468018: validation loss :0.6352324: test loss :2.0143018
# Epoch 92: train loss: 0.6430979: validation loss :0.6318359: test loss :2.0278587
# Epoch 93: train loss: 0.63945925: validation loss :0.6286744: test loss :2.0412261
# Epoch 94: train loss: 0.6358801: validation loss :0.62575173: test loss :2.054406
# Epoch 95: train loss: 0.6323548: validation loss :0.6230718: test loss :2.0673978
# Epoch 96: train loss: 0.6288776: validation loss :0.6206389: test loss :2.0802026
# Epoch 97: train loss: 0.6254429: validation loss :0.61845714: test loss :2.0928211
# Epoch 98: train loss: 0.622044: validation loss :0.6165307: test loss :2.1052525
# Epoch 99: train loss: 0.61867476: validation loss :0.61486447: test loss :2.1174967
# Epoch 100: train loss: 0.61532915: validation loss :0.6134628: test loss :2.1295521
# Epoch 101: train loss: 0.6120008: validation loss :0.61233: test loss :2.1414154
# Epoch 102: train loss: 0.6086835: validation loss :0.6114702: test loss :2.153087
# Epoch 103: train loss: 0.60537124: validation loss :0.6108864: test loss :2.1645663
# Epoch 104: train loss: 0.6020582: validation loss :0.61057997: test loss :2.175856
# Epoch 105: train loss: 0.59873855: validation loss :0.6105512: test loss :2.1869624
# Epoch 106: train loss: 0.59540695: validation loss :0.61079735: test loss :2.1978955
# Epoch 107: train loss: 0.59205836: validation loss :0.61131364: test loss :2.2086716
# Epoch 108: train loss: 0.5886877: validation loss :0.6120927: test loss :2.2193115
# Epoch 109: train loss: 0.58529055: validation loss :0.61312515: test loss :2.2298396
# Epoch 110: train loss: 0.5818625: validation loss :0.6144006: test loss :2.2402828
# Epoch 111: train loss: 0.57839966: validation loss :0.6159086: test loss :2.250667
# Epoch 112: train loss: 0.574898: validation loss :0.6176403: test loss :2.2610145
# Epoch 113: train loss: 0.5713544: validation loss :0.6195894: test loss :2.2713401
# Epoch 114: train loss: 0.5677655: validation loss :0.62175345: test loss :2.2816513
# Epoch 115: train loss: 0.56412846: validation loss :0.6241337: test loss :2.291944
# Epoch 116: train loss: 0.56044084: validation loss :0.6267346: test loss :2.3022113
# Epoch 117: train loss: 0.55670005: validation loss :0.62956166: test loss :2.3124394
# Epoch 118: train loss: 0.5529038: validation loss :0.63262075: test loss :2.3226225
# Epoch 119: train loss: 0.54905003: validation loss :0.63591474: test loss :2.3327608
# Epoch 120: train loss: 0.5451369: validation loss :0.6394428: test loss :2.3428683
# Epoch 121: train loss: 0.5411625: validation loss :0.6432008: test loss :2.3529716
# Epoch 122: train loss: 0.5371257: validation loss :0.6471819: test loss :2.3631053
# Epoch 123: train loss: 0.53302485: validation loss :0.6513797: test loss :2.373305
# Epoch 124: train loss: 0.52885956: validation loss :0.6557904: test loss :2.3835993
# Epoch 125: train loss: 0.52462894: validation loss :0.660416: test loss :2.393999

# %% [markdown]
# ### Question
# Has the test error always decreased or has there come a point where it has started to increase?

# %% [markdown]
# Normally, at some point it starts increaseing in each epoch, meaning the ann is overfitted.

# %% [markdown]
# ### Question
# How do the 3 precision values evolve?

# %% [markdown]
# The train loss always decreases in each epoch. The validation loss and the test loss depends if the ann stats to be overfitted or not so normally fluctuates.

# %% [markdown]
# ### Question
# Which criteria usually stop the training? Why?

# %% [markdown]
# The epochs without improving the validation loss is the one that usually stops the training.

# %% [markdown]
# ### Question
# To which cycle does the ANN returned by the function correspond?

# %% [markdown]
# To the cycle that has the best validation loss.

# %% [markdown]
# # Julia Notes
#
# Julia has a library that allows you to display all kinds of plots in a very simple way.  To load it, simply put `using Plots`, the documentation can be found at http://docs.juliaplots.org/. As always the first should be to install, ifg it is not already installed:

# %%
using Pkg; Pkg.add("Plots");
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\pabno\.julia\environments\v1.9\Project.toml`
#   No Changes to `C:\Users\pabno\.julia\environments\v1.9\Manifest.toml`

# %% [markdown]
# Actually, `Plots.jl` is not a package for displaying plots, but an interface to a set of libraries for displaying plots.  Plots.jl provides a set of functions that allow, in a unified way, to display plots using one or another library, with the same calls.  That is, what Plots.jl does is to interpret the commands and generate the plots using another graphics library, which it refers to as a backend. Therefore, it is possible to change the graphics library (backend) without having to modify the code, since the calls to the corresponding functions are the same for all backends.
#
# So, first of all, after loading `Plots`, is to select the backend you want to work with.  Julia provides a large number of widely used ones, which you have to install in the usual way if you want to use them. If you don't indicate which one you want to use, Julia defaults to choosing one depending on which ones are installed. To see which backend is being used, you can simply type `backend()`.

# %%
using Plots
backend()
# Out:
# Plots.GRBackend()

# %% [markdown]
# Some of the most common backends are: Plotly, PyPlot, PlotlyJS and GR. In general, to use a backend, you simply make a call to a function named after the backend itself, but in lowercase. For the 4 given as examples at the beginning of this paragraph, it would be with calls to `plotly()`, `pyplot()`, `plotlyjs()` and `gr()` respectively. As said before, in case it is not installed you will have to install it in the usual way, writing `Pkg.add("Plotly")`, `Pkg.add("PyPlot")`, `Pkg.add("PlotlyJS")` or `Pkg.add("GR")` respectively.   More information about the different backends can be found at https://docs.juliaplots.org/latest/backends/.

# %%
# Install the pyplot and plotly if you do not have it

# %% [markdown]
# Once the desired backend is loaded, or with the default backend, you can start plotting. The easiest way is to use the plot function, which receives two parameters: the series to be put on the x-axis, and the series to be put on the y-axis, both as vectors, for example:

# %%
plot(1:5, [2, 3, 1, 3, 5])

# %% [markdown]
# In general, if you want to put more than one series on the graph, it is sufficient to specify one column per series in the matrix you pass to it for the y-axis data, for example:

# %%
plot(1:5, [2 1; 3 -1; 1 0; 3 2; 5 4])

# %% [markdown]
# Another way to do this is to add more series to the plot object that has been created. That is, the call to plot returns an object that can be modified by further calls to `plot!` and passing it as the first parameter (remember that when the name of a function ends in `!` the argument passed is modified). The above example could be done in the following way:

# %%
g = plot(1:5, [2, 3, 1, 3, 5])
plot!(g, 1:5, [1, -1, 0, 2, 4])

# %% [markdown]
# Or alternatively:

# %%
g = plot()
plot!(g, 1:5, [2, 3, 1, 3, 5])
plot!(g, 1:5, [1, -1, 0, 2, 4])

# %% [markdown]
# For any of these three possibilities, if this is done in the command interpreter, the graph will appear.  In fact, in the second and third possibilities, more than one graph will appear as you create them. However, if this is done in a script, the graph does not automatically appear.  If we want it to appear, we have to make a call to display in this way:
#
# ```julia
#     display(g)
# ```
#
# Besides the function plot, there are many other functions that allow you to represent other types of graphs and charts with the usual names, such as `heatmap`, `plot3d`, `scatter`, `histogram`, `boxplot`, `violin`, etc., all of them with their corresponding function ending in `!`.  As always, you can consult the help of a function by typing, for example:

# %%
?boxplot
# Out:
# search: boxplot boxplot!
#   boxplot(x, y)
#   boxplot!(x, y)
#
#   Make a box and whisker plot.
#
#   Keyword arguments
#   ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
#
#     •  notch: Bool. Notch the box plot? (false)
#
#     •  whisker_range: Real. Whiskers extend whisker_range*IQR below the
#        first quartile and above the third quartile. Values outside this
#        range are shown as outliers (1.5)
#
#     •  outliers: Bool. Show outliers? (true)
#
#     •  whisker_width: Real or Symbol. Length of whiskers; the options are
#        :match to match the box width, :half, or a number to indicate the
#        total length. (:half)
#
#   Example
#   ≡≡≡≡≡≡≡≡≡
#
#   julia> using StatsPlots
#   julia> boxplot(repeat([1,2,3],outer=100),randn(300))

# %% [markdown]
# Generally speaking, it is desired to add more information to the graphs than just the data used in the graph.  This information usually includes title, labels on the axes, legend, markers at each point, line type, colours, etc.  This is usually done through attributes passed as keywords in function calls, such as `axis`, `label`, `line`, `fill`, `marker`, `ticks`, `title`, `xlabel`, `ylabel`, for example:

# %%
plot(1:5, [2, 3, 1, 3, 5],
    xaxis = "Epoch", yaxis = "Loss value", title = "An plot example",
    marker = :square, color = :red, label = "Serie 1")

# %% [markdown]
# A quick overview of the most common keywords can be found at https://docs.juliaplots.org/latest/attributes/.   On the other hand, https://docs.juliaplots.org/latest/generated/supported/tenéis has a complete list of the different types of series, keywords, markers, line styles and scales supported by each backend.  As you can see, the list of graphs and arguments is quite extensive, which gives you an idea of the enormous possibilities Julia offers when it comes to plotting graphs.
#
# Another common issue when displaying graphs is to combine several graphs within a single window.  There are several methods to do this, the simplest and most commonly used being by using the keyword `layout` in the call to the corresponding function to generate the graph containing all of them.  In this sense, it is the easiest way to generate the graphs independently, and combine them later in a new call using the keyword `layout`, which receives as parameter a tuple with the number of rows and columns of the matrix of graphs, for example:

# %%
p1 = plot(1:4, [1, 3, 4, 2]);
p2 = plot(1:4, [2, 3, 2, 1]);
p3 = plot(1:4, [3, 2, 1, 2]);
plot(p1, p2, p3, layout = (3,1))

# %% [markdown]
# As you could see, the plots asre arrange in a column layout each one in a row, alternatively, if we invert the order the result could be set in a single row as in:

# %%
plot(p1, p2, p3, layout = (1,3))

# %% [markdown]
# More information on how to combine graphics can be found at https://docs.juliaplots.org/latest/layouts/.
#
# Finally, another very common action is to save the generated graphs.  This can be done by means of the savefig function, which receives as parameters the graph to save and the file name. From the extension indicated in the file name, Julia saves the graph in the indicated format. Some of the most typical formats are `pdf`, `png` or `ps`.  Although this is a very easy way to save the graphs, not all file types are supported by all backends. At https://docs.juliaplots.org/latest/output/ you can check the file formats supported by each backend. For exple with the previous example.
#
# ```julia
#     g = plot(p1, p2, p3, layout = (1,3))
#     savefig(g, 'ExampleSingleRow.png')
# ```
